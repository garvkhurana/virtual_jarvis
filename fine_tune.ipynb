# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.193  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Setup complete  (12 CPUs, 15.3 GB RAM, 402.5/475.4 GB disk)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("garv-quaoe").project("custom-workflow-object-detection-a0v8p")
version = project.version(1)
dataset = version.download("yolov11")

# %%
import torch
print(torch.version.cuda)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 12.1
# True
# NVIDIA GeForce GTX 1650

# %%
from ultralytics import YOLO
model = YOLO(r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\runs\detect\yolo11s_finetuned4\weights\best.pt")

# %%
model.train(
    data=r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\Custom Workflow Object Detection.v2i.yolov11\data.yaml",
    epochs=100,
    imgsz=512,         
    batch=4,           
    device=0,          
    half=True,         
    workers=2,
    optimizer="AdamW",
    patience=10,
    cfg=r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\Custom Workflow Object Detection.v2i.yolov11\hyp.yaml",
    name="yolo11s_finetuned_again"
)
# Out:
# Ultralytics 8.3.193  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
model1 = YOLO(r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\runs\detect\yolo11s_finetuned_again\weights\best.pt")

model1.train(
    data=r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\Custom Workflow Object Detection.v2i.yolov11\data.yaml",
    epochs=40,
    imgsz=512,
    batch=4,
    device=0,
    half=True,
    workers=2,
    optimizer="AdamW",
    patience=15,
    cfg=r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\Custom Workflow Object Detection.v2i.yolov11\hyp_optimized.yaml",
    name="yolo11s_finetuned_phase2"
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.194 available  Update with 'pip install -U ultralytics'
# WARNING 'label_smoothing' is deprecated and will be removed in in the future.
# Ultralytics 8.3.193  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
 final_model= YOLO(r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\runs\detect\yolo11s_finetuned_phase2\weights\last.pt")

final_model.train(
    data=r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\Custom Workflow Object Detection.v2i.yolov11\data.yaml",
    epochs=40,
    imgsz=512,
    batch=4,
    device=0,
    half=True,
    workers=2,
    optimizer="AdamW",
    cfg=r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\Custom Workflow Object Detection.v2i.yolov11\last_cycle.yaml",
    name="yolo11s_finetuned_final_model"
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.194 available  Update with 'pip install -U ultralytics'
# WARNING 'label_smoothing' is deprecated and will be removed in in the future.
# Ultralytics 8.3.193  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...
