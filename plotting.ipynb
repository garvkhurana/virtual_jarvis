# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\runs\detect\yolo11s_finetuned4\results.csv")
df.head()
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1  2192.98         2.07023         4.09872         2.24434
# 1      2  2494.80         1.95311         3.73849         2.06757
# 2      3  2828.36         1.86021         3.57439         1.98173
# 3      4  3161.63         1.81163         3.42125         1.92672
# 4      5  3490.13         1.77632         3.31067         1.88533
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.11346            0.24621           0.00901
# 1               0.59153            0.09848           0.02968
# 2               0.52734            0.11947           0.08998
# 3               0.74623            0.12027           0.10286
# 4               0.81445            0.08910           0.13634
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.00292       2.71190       6.95673       3.11066  0.070029
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))
sns.lineplot(ax=axes[0], x=df.index, y="train/box_loss", data=df, label="Box Loss", linewidth=2)
sns.lineplot(ax=axes[0], x=df.index, y="train/cls_loss", data=df, label="Cls Loss", linewidth=2)
sns.lineplot(ax=axes[0], x=df.index, y="train/dfl_loss", data=df, label="DFL Loss", linewidth=2)

axes[0].set_title("YOLO Training Losses", fontsize=14, weight="bold")
axes[0].set_xlabel("Epochs", fontsize=12)
axes[0].set_ylabel("Loss", fontsize=12)
axes[0].legend()
axes[0].grid(True)



sns.lineplot(ax=axes[1], x=df.index, y="val/box_loss", data=df, label="Val Box Loss", linewidth=2)
sns.lineplot(ax=axes[1], x=df.index, y="val/cls_loss", data=df, label="Val Cls Loss", linewidth=2)
sns.lineplot(ax=axes[1], x=df.index, y="val/dfl_loss", data=df, label="Val DFL Loss", linewidth=2)

axes[1].set_title("YOLO Validation Losses", fontsize=14, weight="bold")
axes[1].set_xlabel("Epochs", fontsize=12)
axes[1].set_ylabel("Loss", fontsize=12)
axes[1].legend()
axes[1].grid(True)


plt.suptitle("YOLO Training vs Validation Loss Trends", fontsize=16, weight="bold")
plt.tight_layout()
plt.show()

# %%
fig1, axes1 = plt.subplots(1, 2, figsize=(18, 7))
sns.lineplot(ax=axes1[0], x=df.index, y="metrics/precision(B)", data=df, label="precision", linewidth=2)
sns.lineplot(ax=axes1[0], x=df.index, y="metrics/recall(B)", data=df, label="recall", linewidth=2)

axes1[0].set_title("precision_and_recall_graph", fontsize=14, weight="bold")
axes1[0].set_xlabel("Epochs", fontsize=12)
axes1[0].set_ylabel("precision_and_recall", fontsize=12)
axes1[0].legend()
axes1[0].grid(True)



sns.lineplot(ax=axes1[1], x=df.index, y="metrics/mAP50(B)", data=df, label="map50", linewidth=2)
sns.lineplot(ax=axes1[1], x=df.index, y="metrics/mAP50-95(B)", data=df, label="mAP50-95", linewidth=2)

axes1[1].set_title("map_gain_graph", fontsize=14, weight="bold")
axes1[1].set_xlabel("Epochs", fontsize=12)
axes1[1].set_ylabel("MAP_gain", fontsize=12)
axes1[1].legend()
axes1[1].grid(True)


plt.suptitle("YOLO Training and precision_and_recall_graph and map_gain_graph", fontsize=16, weight="bold")
plt.tight_layout()
plt.show()

# %%
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 60     61  29832.0         1.10892         1.07683         1.45001
# 61     62  30153.7         1.10431         1.06162         1.43002
# 62     63  30479.7         1.09451         1.04404         1.43419
# 63     64  30805.8         1.08560         1.02645         1.42298
# 64     65  31130.8         1.06957         1.00564         1.40933
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 60               0.74283            0.58255           0.65532
# 61               0.66509            0.61838           0.65552
# 62               0.66577            0.61030           0.64558
# 63               0.65219            0.64490           0.66910
# 64               0.66755            0.61947           0.66310
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 60              0.41354       1.41486       1.43970       1.65201  0.000862
# ...

# %%
data=pd.read_csv(r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\runs\detect\yolo11s_finetuned_again\results.csv")
data
# Out:
#     epoch       time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1    311.780         1.60952         2.66422         1.80772
# 1       2    651.947         1.58059         2.59622         1.77068
# 2       3    973.631         1.55723         2.57317         1.75148
# 3       4   1278.710         1.56502         2.60944         1.76202
# 4       5   1584.700         1.56271         2.53868         1.73559
# ..    ...        ...             ...             ...             ...
# 90     91  41550.000         1.08805         1.01829         1.46090
# 91     92  41932.200         1.08724         0.95632         1.45047
# 92     93  42314.000         1.06388         0.92155         1.43474
# 93     94  42696.700         1.06437         0.89591         1.43545
# 94     95  43081.400         1.04847         0.89208         1.42540
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.54061            0.49494           0.51649
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))
sns.lineplot(ax=axes[0], x=data.index, y="train/box_loss", data=data, label="Box Loss", linewidth=2)
sns.lineplot(ax=axes[0], x=data.index, y="train/cls_loss", data=data, label="Cls Loss", linewidth=2)
sns.lineplot(ax=axes[0], x=data.index, y="train/dfl_loss", data=data, label="DFL Loss", linewidth=2)

axes[0].set_title("YOLO Training Losses after data augmented", fontsize=14, weight="bold")
axes[0].set_xlabel("Epochs", fontsize=12)
axes[0].set_ylabel("Loss", fontsize=12)
axes[0].legend()
axes[0].grid(True)



sns.lineplot(ax=axes[1], x=data.index, y="val/box_loss", data=data, label="Val Box Loss", linewidth=2)
sns.lineplot(ax=axes[1], x=data.index, y="val/cls_loss", data=data, label="Val Cls Loss", linewidth=2)
sns.lineplot(ax=axes[1], x=data.index, y="val/dfl_loss", data=data, label="Val DFL Loss", linewidth=2)

axes[1].set_title("YOLO Validation Losses after augmentation", fontsize=14, weight="bold")
axes[1].set_xlabel("Epochs", fontsize=12)
axes[1].set_ylabel("Loss", fontsize=12)
axes[1].legend()
axes[1].grid(True)


plt.suptitle("YOLO Training vs Validation Loss Trends after augmentation", fontsize=16, weight="bold")
plt.tight_layout()
plt.show()

# %%
fig1, axes1 = plt.subplots(1, 2, figsize=(18, 7))
sns.lineplot(ax=axes1[0], x=data.index, y="metrics/precision(B)", data=data, label="precision_after_augmentation", linewidth=2)
sns.lineplot(ax=axes1[0], x=data.index, y="metrics/recall(B)", data=data, label="recall_after_augnmentation", linewidth=2)

axes1[0].set_title("precision_and_recall_graph_after_augmentation", fontsize=14, weight="bold")
axes1[0].set_xlabel("Epochs", fontsize=12)
axes1[0].set_ylabel("precision_and_recall", fontsize=12)
axes1[0].legend()
axes1[0].grid(True)



sns.lineplot(ax=axes1[1], x=data.index, y="metrics/mAP50(B)", data=data, label="map50_after_augmentation", linewidth=2)
sns.lineplot(ax=axes1[1], x=data.index, y="metrics/mAP50-95(B)", data=data, label="mAP50-95_after_augmentation", linewidth=2)

axes1[1].set_title("map_gain_graph_after_augmentation", fontsize=14, weight="bold")
axes1[1].set_xlabel("Epochs", fontsize=12)
axes1[1].set_ylabel("MAP_gain", fontsize=12)
axes1[1].legend()
axes1[1].grid(True)


plt.suptitle("YOLO Training and precision_and_recall_graph and map_gain_graph_after_augmentation", fontsize=16, weight="bold")
plt.tight_layout()
plt.show()

# %%
data.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 90     91  41550.0         1.08805         1.01829         1.46090
# 91     92  41932.2         1.08724         0.95632         1.45047
# 92     93  42314.0         1.06388         0.92155         1.43474
# 93     94  42696.7         1.06437         0.89591         1.43545
# 94     95  43081.4         1.04847         0.89208         1.42540
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 90               0.62827            0.66759           0.67341
# 91               0.70623            0.64541           0.69400
# 92               0.72357            0.63116           0.68960
# 93               0.71827            0.63505           0.71406
# 94               0.68115            0.66579           0.70564
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss   lr/pg0  \
# 90              0.41168       1.42694       1.32197       1.59995  0.00190
# ...

# %%
dataset=pd.read_csv(r"C:\Users\garvk\OneDrive - Bhagwan Parshuram Institute of Technology\Desktop\advance_projects\candice\runs\detect\yolo11s_finetuned_phase2\results.csv")
dataset
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   2542.97         1.30281         1.84831         0.52433
# 1       2   2857.39         1.22932         1.67165         0.50624
# 2       3   3185.88         1.20367         1.60746         0.49956
# 3       4   3506.93         1.19419         1.62013         0.49863
# 4       5   3830.34         1.19608         1.59475         0.49612
# 5       6   4144.91         1.20037         1.58874         0.49709
# 6       7   4444.59         1.19098         1.57438         0.49514
# 7       8   4769.87         1.18515         1.55898         0.49316
# 8       9   5096.80         1.17315         1.53500         0.49172
# 9      10   5417.06         1.19016         1.56035         0.49722
# 10     11   5737.95         1.17111         1.53486         0.49008
# 11     12   6054.30         1.18074         1.54074         0.49347
# 12     13   6382.54         1.16915         1.50635         0.48992
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))
sns.lineplot(ax=axes[0], x=dataset.index, y="train/box_loss", data=dataset, label="Box Loss of phase2", linewidth=2)
sns.lineplot(ax=axes[0], x=dataset.index, y="train/cls_loss", data=dataset, label="Cls Loss of phase2", linewidth=2)
sns.lineplot(ax=axes[0], x=dataset.index, y="train/dfl_loss", data=dataset, label="DFL Loss of phase2", linewidth=2)

axes[0].set_title("YOLO Training Losses after data augmented after phase2", fontsize=14, weight="bold")
axes[0].set_xlabel("Epochs", fontsize=12)
axes[0].set_ylabel("Loss", fontsize=12)
axes[0].legend()
axes[0].grid(True)



sns.lineplot(ax=axes[1], x=dataset.index, y="val/box_loss", data=dataset, label="Val Box Loss of phase2", linewidth=2)
sns.lineplot(ax=axes[1], x=dataset.index, y="val/cls_loss", data=dataset, label="Val Cls Loss of phase2", linewidth=2)
sns.lineplot(ax=axes[1], x=dataset.index, y="val/dfl_loss", data=dataset, label="Val DFL Loss of phase2", linewidth=2)

axes[1].set_title("YOLO Validation Losses after augmentation of phase2", fontsize=14, weight="bold")
axes[1].set_xlabel("Epochs", fontsize=12)
axes[1].set_ylabel("Loss", fontsize=12)
axes[1].legend()
axes[1].grid(True)


plt.suptitle("YOLO Training vs Validation Loss Trends after augmentation of phase2", fontsize=16, weight="bold")
plt.tight_layout()
plt.show()
